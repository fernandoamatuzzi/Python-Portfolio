# %%
class Customer():
  def __init__(self, name, email):
    self.name = name
    self.email = email
    self.purchases = []
  
  def purchase(self, inventory, product):
    inventory_dict = inventory.inventory
    if product in inventory_dict:
      if inventory_dict[product] > 0:
        self.purchases.append(product)
        inventory_dict[product] -= 1
      else:
        print("We are out of stock!")
    else:
      print("We don't have that product!")

  def print_purchases(self):
    print("The customer has purchased:")
    for item in self.purchases:
      print(item.name)

class Product():
  def __init__(self, name, price):
    self.name = name
    self.price = price

class Inventory():
  def __init__(self):
    self.inventory = {}

  def add_product(self, product, quantity):
    if product not in self.inventory:
      self.inventory[product] = quantity
    else:
      self.inventory[product] += quantity

  def print_inventory(self):
    for key, value in self.inventory.items():
      print(key.name + ': ' + str(value))
    print()



customer = Customer('Joe', 'joe@gmail.com')
# print(customer.name)
# print(customer.email)

samsung_watch = Product('Samsung Watch', 299)
# print(samsung_watch.name)
# print(samsung_watch.price)

s10 = Product('S10 Device', 799)
# print(s10.name)
# print(s10.price)

inventory = Inventory()
inventory.add_product(samsung_watch, 100)
# inventory.print_inventory()
inventory.add_product(s10, 498)

inventory.print_inventory()
customer.purchase(inventory, samsung_watch)
customer.purchase(inventory, s10)
inventory.print_inventory()
customer.print_purchases()
# Out:
# Samsung Watch: 100
# S10 Device: 498
#
# Samsung Watch: 99
# S10 Device: 497
#
# The customer has purchased:
# Samsung Watch
# S10 Device
